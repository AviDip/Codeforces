# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/Codeforces
# Out:
# /content/drive/MyDrive/Colab Notebooks/Codeforces

# %%
# !git config --global user.email "avidipto110@gmail.com"
# !git config --global user.name "AviDip"

# %%
# !git init
# !git add .
# !git commit -m "created"
# !git branch -M main
# !git remote add origin https://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@github.com/AviDip/Codeforces.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Codeforces/.git/
# [main fe0d69e] created
#  1 file changed, 1 insertion(+), 1 deletion(-)
# fatal: remote origin already exists.
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git add .
# !git commit -m "FileCreated"
# !git push
# Out:
# [main f194564] FileCreated
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite Codeforces.ipynb (95%)
#  create mode 100644 CodeforcesGit.ipynb
# fatal: could not read Password for 'https://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@github.com': No such device or address
